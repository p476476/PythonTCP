# %% [markdown]
# # This is a simple tcp server test :

# %%
import socket
import threading
import time

class ClientData():
    clientsocket=''
    client_thread=''
    
    def __init__(self,client):
        self.clientsocket = client
        

class SocketServer(socket.socket):
    clients = []
    message = "this is a message."
#     =====================
#     HERE IS SERVER INIT
#     =====================    
    def __init__(self):
        socket.socket.__init__(self)
        #To silence- address occupied!!
        self.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
        self.bind(('0.0.0.0', 5566))
        self.listen(5)

    def run(self):
        print ("Server started")
        try:
            self.accept_clients()
        except Exception as ex:
            print (ex)
        finally:
            print ("Server closed")
            for client in self.clients:
                client.close()
            self.close()
    def decode_data(self,data):
        splited = data.decode("utf-8").split(',')
        return splited 
#     =====================
#     HERE IS TEST FUNCTION
#     =====================
    def sendTime(self, client,args):
        client.send(str.encode(time.strftime("%a %b %d %H:%M:%S %Y", time.localtime())))
        
    def greed(self,client,args):
        client.send(str.encode("Hi "+args))
        
    def disconnect(self,client):
        #Removing client from clients list
        self.clients.remove(client)
        #Client Disconnected
        client.clientsocket.send(str.encode("ByeBye"))
        self.onclose(client)
        #Closing connection with client
        client.clientsocket.close()
        #Closing thread
        if(client.client_thread!=None):
            client.client_thread.exit()

    
    txtToDo= {'what time':sendTime,
              'my name is':greed}
    def recieve(self, client):
        while 1:
            data = client.clientsocket.recv(1024)
            #Message Received
            self.onmessage(client, data)
            if data == b'disconnect':
                break
            else:
                toDo,arg = self.decode_data(data)
                #Closing old thread
                if(client.client_thread!=None):
                    client.client_thread.exit()
                #Start new thread
                client.client_thread=threading.Thread(target=self.txtToDo[toDo],args=(self,client.clientsocket,arg,)).start()
        self.disconnect(client)
    
    def accept_clients(self):
        while 1:
            print("waiting for Client")
            (clientsocket, address) = self.accept()
            
            new_client = ClientData(clientsocket)
            #Adding client to clients list
            self.clients.append(new_client)
            #Client Connected
            self.onopen(clientsocket)
            #Start listening
            threading.Thread(target=self.recieve,args=(new_client,)).start()

    def broadcast(self, message):
        #Sending message to all clients
        for client in self.clients:
            client.clientsocket.send(message)
    # ===================
    # SOME EVENT FUNCTION
    # ===================
    def onopen(self, client):
        print ("Client Connected \n",client)

    def onmessage(self, client, message):
        print ("Client send message ",message)
        
    def onclose(self, client):
        print ("Client Disconnected")

def main():
    server = SocketServer()
    server.run()

if __name__ == "__main__":
    main()
# Out:
# Server started
# waiting for Client
# Client Connected
#  <socket.socket fd=1696, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 5566), raddr=('127.0.0.1', 55762)>
# waiting for Client
# Client got message  b'what time,'
# Client got message  b'my name is,Rem'
# Client got message  b'disconnect'
# Client Disconnected
